# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import urllib.request
import pandas as pd
import time
import requests
from bs4 import BeautifulSoup
import re

# %%
chrome_path = '/Users/sukhmansingh/Downloads/chromedriver'
driver = webdriver.Chrome(chrome_path)

# %%
driver.get("https://www.nykaa.com/")

# %%
# Maximize the browser window
driver.maximize_window()

# %%
#input text field for product
text_field = driver.find_element_by_xpath("""//input[@type="search"]""")
text_field.send_keys("Laneige")
text_field.send_keys(Keys.ENTER)

# %%
# text_field.clear()

# %%
# driver.find_element_by_xpath("""//*[@class="header__search-input form-control"]""").click()

# /html/body/div[1]/div/div/div[1]/div[1]/div[1]/div[3]/div[1]/div[1]/div[2]/div/div/div[2]/div/div[2]/div/input

# %%
driver.get('https://images-static.nykaa.com/media/catalog/product/tr:w-276,h-276,cm-pad_resize/2/7/270283956.jpg')
driver.get_screenshot_as_file("/Users/sukhmansingh/Downloads/nykaa/"+str(count)+".jpg")

# response = request.get('https://images-static.nykaa.com/media/catalog/product/tr:w-276,h-276,cm-pad_resize/2/7/270283903.jpg')
# Out:
# True

# %%
driver.current_url
# Out:
# 'https://images-static.nykaa.com/media/catalog/product/tr:w-276,h-276,cm-pad_resize/4/f/4f4c7048806390587938n.jpg'

# %%
#List of image urls for laneige products

laneige_image_urls = []
images = driver.find_elements_by_tag_name('img')
for image in images:
    if image.get_attribute('class') == 'listing-img':
#         print(image.get_attribute('src'))
        laneige_image_urls.append(image.get_attribute('src'))

laneige_image_urls
print(len(laneige_image_urls))
# Out:
# 42

# %%
print(len(product_list))
# Out:
# 42

# %%
#image capture and save on system

images = driver.find_elements_by_tag_name('img')
# print(images)
# count = 0
for image in images:
    if image.get_attribute('class') == 'listing-img':
        driver.get(image.get_attribute('src'))
#         product_name = list_prod[count]
#         driver.get_screenshot_as_file("/Users/sukhmansingh/Downloads/nykaa/"+product_name+".jpg")
# #         print("/Users/sukhmansingh/Downloads/nykaa/"+product_name+".jpg")
#         count+=1

# %%
#TO-DO--------------------------TO-DO
products_list = driver.find_elements_by_xpath("//*[contains(@class,'product-list-box card desktop-cart')]")
list_prod = []
d = {}
for product in products_list:
    span_list = product.find_elements_by_tag_name('span')
    for span in span_list:
        if (len(span.get_attribute('class')) > 0):
            print(span.text)
        else:
            list_prod.append(span.text)
            for prod in list_prod:
                if bool(re.match('^LANEIGE',prod)):
                    d[prod] = ['sukhman']

product_list.pop(-1)
product_list
# Out:
# OFFERS
# OFFERS
# FEATURED
# FEATURED
#
# ₹1150
#
#
# OFFERS
# OFFERS
# FEATURED
# FEATURED
#
# ₹1150
#
#
# OFFERS
# OFFERS
# FEATURED
# FEATURED
#
# ₹2070
#
#
# OFFERS
# OFFERS
# FEATURED
# FEATURED
#
# ₹1850
#
#
# OFFERS
# OFFERS
# FEATURED
# FEATURED
#
# ₹1850
#
#
# OFFERS
# OFFERS
# FEATURED
# FEATURED
#
# ₹2570
#
#
#
#
#
#
#
#
#
#
#
# ( 2395 )
#
#
# OFFERS
# OFFERS
#
# ₹500
#
#
#
#
#
#
#
#
#
#
#
# ( 3489 )
#
# OFFERS
# OFFERS
#
# ₹700
#
#
#
#
#
#
#
#
#
#
#
# ( 1721 )
#
# OFFERS
# OFFERS
#
# ₹2400
#
#
# OFFERS
# OFFERS
#
# ₹1250
#
#
#
#
#
#
#
#
#
#
#
# ( 273 )
#
# OFFERS
# OFFERS
#
# ₹2390
#
#
#
#
#
#
#
#
#
#
#
# ( 144 )
#
#
# OFFERS
# OFFERS
#
# ₹2070
#
#
#
#
#
#
#
#
#
#
#
# ( 180 )
#
#
# OFFERS
# OFFERS
#
# ₹550
#
#
#
#
#
#
#
#
#
#
#
# ( 360 )
#
# OFFERS
# OFFERS
#
# ₹2390
#
#
#
#
#
#
#
#
#
#
#
# ( 96 )
#
#
# OFFERS
# OFFERS
#
# ₹2400
#
#
#
#
#
#
#
#
#
#
#
# ( 116 )
#
#
# OFFERS
# OFFERS
#
# ₹1850
#
#
# OFFERS
# OFFERS
#
# ₹3500
#
#
#
#
#
#
#
#
#
#
#
# ( 56 )
#
#
# OFFERS
# ...

# %%
list_prod = list(filter(None, list_prod))
product_list = []
product_price_list = []
dict_prod = {}

for prod in list_prod:
    if bool(re.match('^LANEIGE',prod)):
        product_list.append(prod)
    elif bool(re.match('^[₹\d.]+$',prod)):
        product_price_list.append(prod)
 

#appending the product name and product price list into a dictionary

for i in range(len(product_list)):
    product_key = product_list[i]
    price_val = product_price_list[i]
    product_links = laneige_image_urls[i]
    dict_prod[product_key] = [price_val, product_links]
# Out:
# 43

# %%
# print(len(product_list))
product_list.pop(-1)
product_list
# Out:
# ['LANEIGE Lip Sleeping Mask Grapefruit',
#  'LANEIGE Lip Sleeping Mask Apple lime',
#  'LANEIGE Cica Sleeping Mask',
#  'LANEIGE Cream Skin Refiner',
#  'LANEIGE HYDRATION-TO-GO! For Normal to Dry Skin',
#  'LANEIGE Soothing and Hydrating Combo Set',
#  'LANEIGE Lip Sleeping Mask Berry',
#  'LANEIGE Water Sleeping Mask',
#  'LANEIGE White Dew Tone Up Fluid SPF35 PA++',
#  'LANEIGE Water Bank Hydro Essence',
#  'LANEIGE Water Bank Moisture Cream',
#  'LANEIGE Eye Sleeping Mask',
#  'LANEIGE Multi Deep Clean Cleanser',
#  'LANEIGE Water Bank Gel Cream',
#  'LANEIGE White Dew Tone-Up Cream',
#  'LANEIGE HYDRATION-TO-GO! For Combination to Oily Skin',
#  'LANEIGE White Dew Original Ampoule Essence',
#  'LANEIGE Watery Sun Cream SPF50+ PA++++',
#  'LANEIGE Water Bank Double Gel Soothing Mask_EX Pack of 5',
#  'LANEIGE Water Pocket White Plus Renew Whitening Sheet Mask',
#  'LANEIGE Essential Power Skin Refiner Light',
#  'LANEIGE Moist Cream Cleanser',
#  'LANEIGE Water Bank Eye Gel_EX',
# ...

# %%
print(len(product_list))

for i in range(len(product_list)):
    product_key = product_list[i]
    price_val = product_price_list[i]
    product_links = laneige_image_urls[i]
    dict_prod[product_key] = [price_val, product_links]
    
dict_prod
# Out:
# 42
# {'LANEIGE Lip Sleeping Mask Grapefruit': ['₹1150',
#   'https://images-static.nykaa.com/media/catalog/product/tr:w-276,h-276,cm-pad_resize/4/f/4f4c7048806390587938n.jpg'],
#  'LANEIGE Lip Sleeping Mask Apple lime': ['₹1150',
#   'https://images-static.nykaa.com/media/catalog/product/tr:w-276,h-276,cm-pad_resize/c/1/c1177048806390587754n.jpg'],
#  'LANEIGE Cica Sleeping Mask': ['₹2070',
#   'https://images-static.nykaa.com/media/catalog/product/tr:w-276,h-276,cm-pad_resize/6/a/6a877048809608287750n.png'],
#  'LANEIGE Cream Skin Refiner': ['₹1850',
#   'https://images-static.nykaa.com/media/catalog/product/tr:w-276,h-276,cm-pad_resize/f/b/fb0b7048809585113820__1_n.jpg'],
#  'LANEIGE HYDRATION-TO-GO! For Normal to Dry Skin': ['₹1850',
#   'https://images-static.nykaa.com/media/catalog/product/tr:w-276,h-276,cm-pad_resize/8/8/8809643076371_f2.jpg'],
#  'LANEIGE Soothing and Hydrating Combo Set': ['₹2570',
# ...

# %%
if (len(span.get_attribute('class')) > 0): 
            print(span.text)
        elif (len(span.get_attribute('class')) == 0):
            if bool(re.match('^LANEIGE',span.text)):
                list_prod.append(span.text)

# %%
list_prod = list(filter(None, list_prod))
print(list_prod)
# Out:
# ['LANEIGE Water Bank Gel Cream', 'LANEIGE Essential Power Skin Refiner Light', 'LANEIGE Moist Cream Cleanser', 'LANEIGE White Dew Tone-Up Cream', 'LANEIGE Clearing & Nourishing Two Tone Sheet Mask', 'LANEIGE Eye Sleeping Mask', 'LANEIGE Lip Sleeping Mask Berry', 'LANEIGE Water Sleeping Mask', 'LANEIGE Water Bank Hydro Essence', 'LANEIGE Water Bank Moisture Cream', 'LANEIGE Multi Deep Clean Cleanser', 'LANEIGE White Dew Original Ampoule Essence', 'LANEIGE Water Bank Double Gel Soothing Mask_EX Pack of 5', 'LANEIGE Water Pocket White Plus Renew Whitening Sheet Mask', 'LANEIGE White Dew Skin Refiner', 'LANEIGE Water Pocket Clear C Skin Purifying Sheet Mask', 'LANEIGE Water Bank Eye Gel_EX', 'LANEIGE Water Pocket Sparkling Brightening Sheet Mask', 'LANEIGE Water Bank Hydro Mist', 'LANEIGE White Dew Milky Cleanser']

# %%
file = ('<div class="product-list-box card desktop-cart"><div class="tags-offer-container"><span class="tags"><span class="offer">Offer</span></span><span class="tags "><span class="featured">Featured</span></span></div><a target="_blank" href="/laneige-water-bank-gel-cream/p/363852?ptype=product&amp;productId=363852&amp;skuId=363852&amp;categoryId=8242"><div class="row"><div class="col-xs-12 card-img-container "><div class="card-img"><div style="height: 100%; width: 100%; display: inline-block;"><img class="listing-img" src="https://images-static.nykaa.com/media/catalog/product/tr:w-276,h-276,cm-pad_resize/2/7/270283903.jpg" alt="LANEIGE Water Bank Gel Cream" style=""><span></span></div></div></div><div class="col-xs-12"><div class="m-content__product-list__title"><h2 title="LANEIGE Water Bank Gel Cream"><span>LANEIGE Water Bank Gel Cream</span></h2></div><div class="clearfix m-content__product-list__price" itemscope=""><div class="price-info"><span class="post-card__content-price-price"></span><span><span class="post-card__content-price-offer"><!-- react-text: 1330 -->₹<!-- /react-text --><!-- react-text: 1331 -->2390<!-- /react-text --><!-- react-text: 1332 --> <!-- /react-text --></span></span></div></div><div class="m-content__product-list__ratings"><span class="luxury_star" type="hidden"><span style="cursor: auto; display: inline-block; position: relative;"><span class="glyphicon glyphicon-star-empty"></span><span style="display: inline-block; position: absolute; overflow: hidden; top: 0px; left: 0px; width: 100%;"><span class="glyphicon glyphicon-star"></span></span></span><span style="cursor: auto; display: inline-block; position: relative;"><span class="glyphicon glyphicon-star-empty"></span><span style="display: inline-block; position: absolute; overflow: hidden; top: 0px; left: 0px; width: 100%;"><span class="glyphicon glyphicon-star"></span></span></span><span style="cursor: auto; display: inline-block; position: relative;"><span class="glyphicon glyphicon-star-empty"></span><span style="display: inline-block; position: absolute; overflow: hidden; top: 0px; left: 0px; width: 100%;"><span class="glyphicon glyphicon-star"></span></span></span><span style="cursor: auto; display: inline-block; position: relative;"><span class="glyphicon glyphicon-star-empty"></span><span style="display: inline-block; position: absolute; overflow: hidden; top: 0px; left: 0px; width: 100%;"><span class="glyphicon glyphicon-star"></span></span></span><span style="cursor: auto; display: inline-block; position: relative;"><span class="glyphicon glyphicon-star-empty"></span><span style="display: inline-block; position: absolute; overflow: hidden; top: 0px; left: 0px; width: 30%;"><span class="glyphicon glyphicon-star"></span></span></span></span><span class="luxury_clr"><!-- react-text: 1356 --> ( <!-- /react-text --><!-- react-text: 1357 -->96<!-- /react-text --><!-- react-text: 1358 --> )<!-- /react-text --></span></div><div><div class="variant-wrapper"></div></div></div></div></a><div class="m-content__product-list__btn-wrap desktop-card-wrapper"><div class="card-bottom-actions"><div><div><div class="listing_wishlist false"><span class="wishListIconWrapper"><svg xmlns="http://www.w3.org/2000/svg" class="heart-icon-outline" width="23" height="20" viewBox="0 0 23 20"><title>Wishlist</title><path class="heart-icon-path" fill="#fff" stroke="currentColor" d="M11.4967297,19.0021565 C12.1501607,18.4744665 15.7313591,16.1461023 16.6556949,15.4660553 C20.4639993,12.6642314 22.5,9.83806845 22.500204,6.31427989 C22.4080534,3.08900922 19.7336922,0.5 16.5,0.5 C14.6798666,0.5 13.0132876,1.30878098 11.8904344,2.71234752 L11.5,3.20039053 L11.1095656,2.71234752 C9.98671236,1.30878098 8.32013337,0.5 6.5,0.5 C3.16873226,0.5 0.5,3.08355995 0.5,6.3 C0.5,9.87466924 2.55294628,12.7216506 6.38828771,15.5301224 C7.34346545,16.229562 10.7334347,18.4195137 11.4967297,19.0021565 Z"></path></svg></span></div></div></div><button class="primary-btn nk-btn combo-add-to-btn luxury_plpButton atc-simple m-content__product-list__cart-btn  "><span class="mkr-New-Shopping-Bag font-mkr"></span><!-- react-text: 1372 -->&nbsp;<!-- /react-text --><!-- react-text: 1373 -->ADD TO BAG<!-- /react-text --></button></div></div><div class="desktop-variant hide-dialog"><div class="notify__item-overlay"><div class="out-of-stock-text-wrap">Out of Stock</div><button class="close-popup"><i class="fa fa-close"></i></button></div></div></div>')
soup = BeautifulSoup(file,'lxml')

# %%
# soup.find_all('span')

# %%
regex = re.compile('^[₹\d.]+$')

string1 = "₹7000000"

bool(regex.match(string1))
# Out:
# False
